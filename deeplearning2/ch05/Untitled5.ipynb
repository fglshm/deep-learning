# %%
import sys
sys.path.append('..')
import matplotlib.pyplot as plt
import numpy as np
from common.optimizer import SGD
from dataset import ptb
from simple_rnnlm import SimpleRnnlm

# initialize the hyper parameters
batch_size = 10
wordvec_size = 100
hidden_size = 100
time_size = 5
lr = 0.1
max_epoch = 100

# load data
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_size = 1000
corpus = corpus[:corpus_size]
vocab_size = int(max(corpus) + 1)

xs = corpus[:-1]
ts = corpus[1:]
data_size = len(xs)
print('corpus size: %d, vocabulary size: %d' % (corpus_size, vocab_size))

max_iters = data_size // (batch_size * time_size)
time_idx = 0
total_loss = 0
loss_count = 0
ppl_list = []

model = SimpleRnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)

jump = (corpus_size - 1) // batch_size
offsets = [i * jump for i in range(batch_size)]

for epoch in range(max_epoch):
    for iter in range(max_iters):
        batch_x = np.empty((batch_size, time_size), dtype='i')
        batch_t = np.empty((batch_size, time_size), dtype='i')
        for t in range(time_size):
            for i, offset in enumerate(offsets):
                batch_x[i, t] = xs[(offset + time_idx) % data_size]
                batch_t[i, t] = ts[(offset + time_idx) % data_size]
            time_idx += 1
        
        loss = model.forward(batch_x, batch_t)
        model.backward()
        optimizer.update(model.params, model.grads)
        total_loss += loss
        loss_count += 1
    
    ppl = np.exp(total_loss / loss_count)
    print('epoch %d | perplexity %.2f' % (epoch + 1, ppl))
    total_loss, loss_count = 0, 0
# Out:
# corpus size: 1000, vocabulary size: 418
# epoch 1 | perplexity 408.86
# epoch 2 | perplexity 298.10
# epoch 3 | perplexity 230.38
# epoch 4 | perplexity 217.98
# epoch 5 | perplexity 207.37
# epoch 6 | perplexity 202.58
# epoch 7 | perplexity 198.85
# epoch 8 | perplexity 196.50
# epoch 9 | perplexity 191.31
# epoch 10 | perplexity 192.50
# epoch 11 | perplexity 188.17
# epoch 12 | perplexity 191.69
# epoch 13 | perplexity 190.39
# epoch 14 | perplexity 190.47
# epoch 15 | perplexity 189.24
# epoch 16 | perplexity 184.93
# epoch 17 | perplexity 183.75
# epoch 18 | perplexity 180.25
# epoch 19 | perplexity 181.79
# epoch 20 | perplexity 182.59
# epoch 21 | perplexity 181.20
# epoch 22 | perplexity 176.38
# epoch 23 | perplexity 175.20
# epoch 24 | perplexity 175.59
# epoch 25 | perplexity 173.35
# epoch 26 | perplexity 171.39
# epoch 27 | perplexity 167.57
# epoch 28 | perplexity 165.10
# epoch 29 | perplexity 161.58
# epoch 30 | perplexity 156.91
# epoch 31 | perplexity 156.30
# epoch 32 | perplexity 153.75
# epoch 33 | perplexity 152.54
# epoch 34 | perplexity 147.19
# epoch 35 | perplexity 143.54
# epoch 36 | perplexity 140.43
# epoch 37 | perplexity 134.79
# epoch 38 | perplexity 130.65
# epoch 39 | perplexity 125.21
# epoch 40 | perplexity 120.66
# epoch 41 | perplexity 120.47
# epoch 42 | perplexity 112.60
# epoch 43 | perplexity 107.71
# epoch 44 | perplexity 104.22
# epoch 45 | perplexity 100.66
# epoch 46 | perplexity 98.02
# epoch 47 | perplexity 93.22
# epoch 48 | perplexity 86.07
# epoch 49 | perplexity 83.82
# epoch 50 | perplexity 79.31
# epoch 51 | perplexity 74.36
# epoch 52 | perplexity 71.84
# epoch 53 | perplexity 66.58
# epoch 54 | perplexity 65.55
# epoch 55 | perplexity 59.95
# epoch 56 | perplexity 58.70
# epoch 57 | perplexity 55.64
# epoch 58 | perplexity 50.59
# epoch 59 | perplexity 48.30
# epoch 60 | perplexity 46.08
# epoch 61 | perplexity 45.83
# epoch 62 | perplexity 42.02
# epoch 63 | perplexity 38.63
# epoch 64 | perplexity 36.15
# epoch 65 | perplexity 35.25
# epoch 66 | perplexity 32.82
# epoch 67 | perplexity 31.09
# epoch 68 | perplexity 28.49
# epoch 69 | perplexity 27.93
# epoch 70 | perplexity 26.60
# epoch 71 | perplexity 25.06
# epoch 72 | perplexity 23.60
# epoch 73 | perplexity 22.58
# epoch 74 | perplexity 20.99
# epoch 75 | perplexity 20.61
# epoch 76 | perplexity 18.73
# epoch 77 | perplexity 18.42
# epoch 78 | perplexity 17.43
# epoch 79 | perplexity 16.31
# epoch 80 | perplexity 16.01
# epoch 81 | perplexity 15.64
# epoch 82 | perplexity 14.50
# epoch 83 | perplexity 13.64
# epoch 84 | perplexity 12.40
# epoch 85 | perplexity 12.29
# epoch 86 | perplexity 11.46
# epoch 87 | perplexity 11.55
# epoch 88 | perplexity 10.45
# epoch 89 | perplexity 10.37
# epoch 90 | perplexity 9.62
# epoch 91 | perplexity 9.29
# epoch 92 | perplexity 8.73
# epoch 93 | perplexity 8.70
# epoch 94 | perplexity 7.68
# epoch 95 | perplexity 7.43
# epoch 96 | perplexity 6.93
# epoch 97 | perplexity 6.65
# epoch 98 | perplexity 6.43
# epoch 99 | perplexity 6.07
# epoch 100 | perplexity 6.09
